# %%
from pyspark.sql.functions import * 
from pyspark.sql.types import *

# %%
spark.conf.set("fs.azure.account.auth.type.adlsonpremworkstorage.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.adlsonpremworkstorage.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.adlsonpremworkstorage.dfs.core.windows.net", "5c375edb-d0cf-b7-8345-8c27f044dac7")
spark.conf.set("fs.azure.account.oauth2.client.secret.adlsonpremworkstorage.dfs.core.windows.net", "gYO8Q~AS0S_oc_gyqMvrwvtp0Fj3VuyN~3dbKU")
spark.conf.set("fs.azure.account.oauth2.client.endpoint.adlsonpremworkstorage.dfs.core.windows.net", "https://login.microsoftonline.com/2c4ae925-c378-47f0-84eb-ea2712bf3249/oauth2/token")

# %%
dbutils.fs.ls("abfss://bronze@adlsonpremworkstorage.dfs.core.windows.net/HumanResources/EmployeePayHistory/")

# %%
df = spark.read.format("parquet").option("header","true").option("inferSchema","true").load("abfss://bronze@adlsonpremworkstorage.dfs.core.windows.net/HumanResources/EmployeePayHistory/EmployeePayHistory.parquet")

# %%
df=df.withColumn('RateChangeDate', to_date('RateChangeDate', 'MM/dd/yyyy HH:mm:ss.SSS').alias('RateChangeDate'))
df = df.withColumn('ModifiedDate', to_date('ModifiedDate', 'MM/dd/yyyy HH:mm:ss.SSS').alias('ModifiedDate'))
df = df.withColumn('Rate', df['Rate'].cast(DoubleType()))
df.display()

# %%
df.coalesce(1).write.mode("overwrite").option("header", "true").parquet("abfss://silver@adlsonpremworkstorage.dfs.core.windows.net/HumanResources/EmployeePayHistory/")
