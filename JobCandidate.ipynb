# %%
spark.conf.set("fs.azure.account.auth.type.adlsonpremworkstorage.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.adlsonpremworkstorage.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.adlsonpremworkstorage.dfs.core.windows.net", "5c375edb-d0cf-45b7-8345-8c27f044dac7")
spark.conf.set("fs.azure.account.oauth2.client.secret.adlsonpremworkstorage.dfs.core.windows.net", "gYO8Q~AS0S_L1oc_gyqMvrwvtp0Fj3VuyN~3dbKU")
spark.conf.set("fs.azure.account.oauth2.client.endpoint.adlsonpremworkstorage.dfs.core.windows.net", "https://login.microsoftonline.com/2c4ae925-c378-47f0-84eb-ea2712bf3249/oauth2/token")

# %%
from  pyspark.sql import  functions as F  

from  pyspark.sql.types import *
df = spark.read.format("parquet").load("abfss://bronze@adlsonpremworkstorage.dfs.core.windows.net/HumanResources/JobCandidate/JobCandidate.parquet")

# %%
df.show()

# %%
df=df.drop('Resume').drop('ModifiedDate')

# %%
df.show()

# %%
df.dtypes

# %%
df_null= df.select([F.col(c).isNull().alias(c) for c in df.columns]).agg(*[F.max(F.col(c)).alias(c) for c in df.columns])
df_null.show()

# %%
df=df.dropna()

# %%
df.show()

# %%
df.coalesce(1).write.mode("overwrite").format("delta").save("abfss://silver@adlsonpremworkstorage.dfs.core.windows.net/HumanResources/JobCandidate/")
